# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('C:/Users/yn/Desktop/Yuvi/DataTrained/InternshipProjects/CustomerRetentionDataset.csv')
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df=df.rename(columns={'1Gender of respondent':'Gender',
                      '2 How old are you? ':'Age',
                      '3 Which city do you shop online from?':'City',
                      '4 What is the Pin Code of where you shop online from?':'Pincode',
                      '5 Since How Long You are Shopping Online ?':'YearsOfUsage',
                      '6 How many times you have made an online purchase in the past 1 year?':'NoOfPurchaseInLastYear',
                      '7 How do you access the internet while shopping on-line?':'InternetType',
                      '8 Which device do you use to access the online shopping?':'DeviceType',
                      '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ':'ScreenSizeOfDevice',
                      '10 What is the operating system (OS) of your device?\t\t\t\t                                          ':'DeviceOS',
                      '11 What browser do you run on your device to access the website?\t\t\t                                                          ':'Browser',
                      '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ':'ChannelUsed-FirstVist',
                      '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ':'ChannelUsed-AfterFirstVist',
                      '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ':'TimeTakenForOnePurchase',
                      '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ':'PaymentOption',
                      '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ':'AbandonShopping',
                      '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ':'ReasonForAbandonShopping',
                      '18 The content on the website must be easy to read and understand':'Rating-WebsiteContentUnderstandable',
                      '19 Information on similar product to the one highlighted  is important for product comparison':'Rating-ComparisionInfo',
                      '20 Complete information on listed seller and product being offered is important for purchase decision.':'Rating-ProdcutOffer',
                      '21 All relevant information on listed products must be stated clearly':'Rating-ProductInfo',
                      '22 Ease of navigation in website':'Rating-EaseOfWebsiteNavigation',
                      '23 Loading and processing speed':'Rating-ProcessingSpeed',
                      '24 User friendly Interface of the website':'Rating-UserFriendly',
                      '25 Convenient Payment methods':'Rating-PaymentMethod',
                      '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time':'Rating-TransactionTrust',
                      '27 Empathy (readiness to assist with queries) towards the customers':'Rating-EmpathyTowardsCustomer',
                      '28 Being able to guarantee the privacy of the customer':'Rating-CustomerPrivacy',
                      '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)':'Rating-AvailablityOfCommunicationChannels',
                      '30 Online shopping gives monetary benefit and discounts':'Rating-MonetaryBenefits&Discounts',
                      '31 Enjoyment is derived from shopping online':'Rating-Enjoyment',
                      '32 Shopping online is convenient and flexible':'Rating-Convenient&Flexible',
                      '33 Return and replacement policy of the e-tailer is important for purchase decision':'Rating-Return&ReplacementPloicy',
                      '34 Gaining access to loyalty programs is a benefit of shopping online':'Rating-AccesstoLoyaltyPrograms',
                      '35 Displaying quality Information on the website improves satisfaction of customers':'Rating-DisplayingQualityInformation',
                      '36 User derive satisfaction while shopping on a good quality website or application':'Rating-Satisfaction',
                      '37 Net Benefit derived from shopping online can lead to users satisfaction':'Rating-NetBenefit',
                      '38 User satisfaction cannot exist without trust':'Rating-SatisfactionWithTrust',
                      '39 Offering a wide variety of listed product in several category':'Rating-VarietyOfProductsWithCategory',
                      '40 Provision of complete and relevant product information':'Rating-ReleventProductInfo',
                      '41 Monetary savings':'Rating-MonetarySaving',
                      '42 The Convenience of patronizing the online retailer':'Rating-ConvenienceOfPatronizing',
                      '43 Shopping on the website gives you the sense of adventure':'Rating-SenseOfAdventure',
                      '44 Shopping on your preferred e-tailer enhances your social status':'Rating-EnhancesSocialStatus',
                      '45 You feel gratification shopping on your favorite e-tailer':'Rating-FeelingGratification',
                      '46 Shopping on the website helps you fulfill certain roles':'Rating-HelpsToFulfilCertainRoles',
                      '47 Getting value for money spent':'Rating-ValueForMoenySpent',
                      'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ':'OnlineRetailers',
                      'Easy to use website or application':'OnlineRetailers-EasyWebsite/Application',
                      'Visual appealing web-page layout':'OnlineRetailers-Visual/PageLayout',
                      'Wild variety of product on offer':'OnlineRetailers-VarietyOfOffer',
                      'Complete, relevant description information of products':'OnlineRetailers-ReleventInfoOfProducts',
                      'Fast loading website speed of website and application':'OnlineRetailers-SpeedOfWebsite/Application',
                      'Reliability of the website or application':'OnlineRetailers-RelaiabilityOfWebsite/Application',
                      'Quickness to complete purchase':'OnlineRetailers-QuickPurchase',
                      'Availability of several payment options':'OnlineRetailers-SeveralPaymentOptions',
                      'Speedy order delivery ':'OnlineRetailers-SpeedDelivery',
                      'Privacy of customers’ information':'OnlineRetailers-CustomerInfoPrivacy',
                      'Security of customer financial information':'OnlineRetailers-SecurityOfCustomerFinancialInfo',
                      'Perceived Trustworthiness':'OnlineRetailers-TrustWorthy',
                      'Presence of online assistance through multi-channel':'OnlineRetailers-OnlineAssistance',
                      'Longer time to get logged in (promotion, sales period)':'OnlineRetailers-LongerTimeToLogin',
                      'Longer time in displaying graphics and photos (promotion, sales period)':'OnlineRetailers-LongerTimeToDisplayGraphics&Photos',
                      'Late declaration of price (promotion, sales period)':'OnlineRetailers-LateDeclarationOfPrice',
                      'Longer page loading time (promotion, sales period)':'OnlineRetailers-LongerPageLoadingTime',
                      'Limited mode of payment on most products (promotion, sales period)':'OnlofeRetailers-LimitedModeToPayment',
                      'Longer delivery period':'OnlineRetailers-LongerDeliveryPeriod',
                      'Change in website/Application design':'OnlineRetailers-ChangeInWebsite/ApplicationDesign',
                      'Frequent disruption when moving from one page to another':'OnlineRetailers-FrequentDisruptionWhenNavigating',
                      'Website is as efficient as before':'OnlineRetailers-WebsiteEfficiency',
                      'Which of the Indian online retailer would you recommend to a friend?':'OnlineRetailers-RecommendToFriends'})

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'City', 'Pincode', 'YearsOfUsage',
#        'NoOfPurchaseInLastYear', 'InternetType', 'DeviceType',
#        'ScreenSizeOfDevice', 'DeviceOS', 'Browser', 'ChannelUsed-FirstVist',
#        'ChannelUsed-AfterFirstVist', 'TimeTakenForOnePurchase',
#        'PaymentOption', 'AbandonShopping', 'ReasonForAbandonShopping',
#        'Rating-WebsiteContentUnderstandable', 'Rating-ComparisionInfo',
#        'Rating-ProdcutOffer', 'Rating-ProductInfo',
#        'Rating-EaseOfWebsiteNavigation', 'Rating-ProcessingSpeed',
#        'Rating-UserFriendly', 'Rating-PaymentMethod',
#        'Rating-TransactionTrust', 'Rating-EmpathyTowardsCustomer',
#        'Rating-CustomerPrivacy', 'Rating-AvailablityOfCommunicationChannels',
#        'Rating-MonetaryBenefits&Discounts', 'Rating-Enjoyment',
#        'Rating-Convenient&Flexible', 'Rating-Return&ReplacementPloicy',
#        'Rating-AccesstoLoyaltyPrograms', 'Rating-DisplayingQualityInformation',
# ...

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# We do not have any missing value in the data set.

# %%
for col in df.columns:
    print(col)
    print("==================================")
    print(df[col].value_counts(),'\n')
# Out:
# Gender
# ...
# Female    181
# Male       88
# Name: Gender, dtype: int64
#
# Age
# ...
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: Age, dtype: int64
#
# City
# ...
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: City, dtype: int64
#
# Pincode
# ...
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173229     9
# 173212     9
# 250001     9
# 122018     8
# 560037     8
# 132036     8
# 560010     8
# 110011     7
# 110008     7
# 201306     7
# 110014     6
# 110018     6
# 201008     5
# 201009     5
# 201305     5
# 201312     5
# 244001     5
# 530068     5
# 201005     4
# 110009     4
# 110042     4
# 110039     4
# 110030     4
# 201304     4
# 122009     4
# 201303     4
# 560018     4
# ...

# %%
df['NoOfPurchaseInLastYear']=df['NoOfPurchaseInLastYear'].replace({'42 times and above':'41 times and above'})
df['InternetType']=df['InternetType'].replace({'Mobile internet':'Mobile Internet'})

# %% [markdown]
# ## Univariate Analysis

# %%
def label_function(val):
    return f'{val / 100 * len(df):.0f} : {val:.0f}%'

# %%
customer_info_features=['Gender','Age','City']
for col in df.columns:
    plt.figure(figsize=(10,6))
    sns.countplot(df[col])
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# 1. We have more female customers than male customers.
# 2. 31-40 years age group has the highest number of customers and followed by 21-30 and 41-50 age groups.
# 3. Above 51 and less than 20 years age group customers are very less.
# 4. The highest number of online shopping is from the city Delhi.In the city Bullandshahr, its very less.
# 5. From the pincode 201308, we have high number of online shopping than other places.
# 6. Customers who are using online shopping for more than 4 years are higher than who are using less than 4 years.
# 7. More number of customers purchased less than 10 times in the last 1 year and very less number of customers only purchased more than 42 times.
# 8. Most of the customers using mobile internet while doing online shopping.
# 9. Smartphone is mostly used by customers for online shopping.
# 10. More number of customers using Winows OS and followed by Android.
# 11. Majority of the customers use Google chrome as the browser.
# 12. Majority of the customers used search engine to visit the online stores for the first time.
# 13. Customers uses search engine as well as application for online shoppping after the first visit.
# 14. Most of the times more than 15 mins taken for one purchase.
# 15. More number of customers uses credit/debit card as payment options and followed by COD.
# 16. Abandon shopping counts is not very frequent.
# 17. Most of the times reason for abandon shopping is better alternative offer.
# 18. Most customers strongly agree or agree about the website content understandability, info given about the product, ease of website navigation, processing speed, userfriendly, payment options,transaction trust,empthy towards customer,customer privacy,availability of cummunication channels,monetary benefits and discounts.
# 19. More number of customers are enjoying their shopping and followed by customer who are indifferent.
# 20. Customers are strongly agree or agree convenience&flexibility, return and replacement policy,access to loyalty programs help,displaying quality information, satisfcation,netbenefit,satisfaction with trust,relevent product info,monetary saving,convenience of patronizing.
# 21. More number of customer who feels indifferent when we say it enhances social status,feeling gratification,helps to fulfill certain roles.
# 22. More number of customers almost purchased in all the online stores(Amazon,flipkart,paytm,myntra,snapdeal).
# 23. More number of customers says amazon and flipkart has better visual and page layout than other online shopping websites and followed by amazon.
# 24. More number of customers says amazon and flipkart provides variety of offers and followed by amazon is the next highest online retailer.
# 25. Many customers says amaon and flipkart provides the better relavent product info than others.
# 26. Many customers says amazon website/application is high speed than others and flipkart is low speed than others.
# 27. Amazon is rated by more number of customers as best relaiable website and application.The leaast relaiable website is the paytm.com.
# 28. Amazon is rated by more customers as best online store for qucik purchase.
# 29. More number of customers says amazon and flipkart has more payment options than other online stores.
# 30. Most customers rated amazon does the speedy delivery.
# 31. More customers says amazon gaurantees the customer information privacy.
# 32. More users rated amazon has the better security for customer financial information.
# 33. More customers feel amzon is the trust worthy website for online shopping.
# 34. Amazon has better online assistance options.
# 35. More customers says amazon takes longer time to get logged in.
# 36. Amazon and flipkart takes longer time to display the images.
# 37. Most of the custoemrs says, Mytra does the late declarion on prices.
# 38. Myntra and Paytm takes longer page loading time than others.
# 39. Most of the times, snapdeal has limited mode of payment for products.
# 40. Paytm and snapdeal takes longer time to deliver the products.
# 41. Amazon does the change in website/application design.
# 42. More number of customers says amazon has frequest disruption when moving from one page to another page.
# 43. More customers rated amazon has the better website efficiency than others and followed by flipkart.Very less number of customers rated snapdeal for the website efficiency.
# 44. Most of the customers recommending amazon to their freinds and followed by flipkart.

# %% [markdown]
# ## Bivariate Analysis

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 5))
df.groupby('YearsOfUsage').size().plot(kind='pie',ax=ax1,autopct=label_function)
ax1.set_ylabel('YearsOfUsage')
sns.countplot(df['YearsOfUsage'],hue=df['Gender'])
plt.xticks(rotation=90)
plt.show()

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 5))
df.groupby('Age').size().plot(kind='pie',ax=ax1,autopct=label_function)
ax1.set_ylabel('Age')
sns.countplot(df['Age'],hue=df['Gender'])
plt.xticks(rotation=90)
plt.show()

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2, figsize=(18, 6))
df.groupby('OnlineRetailers-RecommendToFriends').size().plot(kind='pie',ax=ax1,autopct=label_function)
ax1.set_xlabel('OnlineRetailers-RecommendToFriends')
ax1.set_ylabel('')
sns.countplot(df['OnlineRetailers-RecommendToFriends'],hue=df['Age'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. From the above plot we could see that all the age group customers mostly recommend amazon to their freinds.
# 2. The second highest recommended website is flipkart and the customers whose age between 31 to 40, highly recommending flipkart to their friends.

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2, figsize=(18, 6))
df.groupby('OnlineRetailers-FrequentDisruptionWhenNavigating').size().plot(kind='pie',ax=ax1,autopct=label_function)
ax1.set_xlabel('OnlineRetailers-FrequentDisruptionWhenNavigating')
ax1.set_ylabel('')
sns.countplot(df['OnlineRetailers-FrequentDisruptionWhenNavigating'],hue=df['InternetType'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. Mostly when customers using their mobile internet they face frequent disruption while navigating in the online shopping website.
# 2. Customers face frequent disruption with snapdeal site even when using wifi. It shows that website instability.
# 3. Following to snapdeal, myntra also has disruption while accessing the website or application.

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2, figsize=(18, 6))
df.groupby('OnlineRetailers-FrequentDisruptionWhenNavigating').size().plot(kind='pie',ax=ax1,autopct=label_function)
ax1.set_xlabel('OnlineRetailers-FrequentDisruptionWhenNavigating')
ax1.set_ylabel('')
sns.countplot(df['OnlineRetailers-FrequentDisruptionWhenNavigating'],hue=df['Browser'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. GoogleChrome is mostly used by customers, Myntra has the higest disruption when using google chrome browser for onine shopping.
# 2. Amazon website has disruption while using chorme as well as Opera.
# 3. Seems Amazon and flipkart and snapdeal websites not performing well with Safari browser.

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2, figsize=(18, 6))
df.groupby('TimeTakenForOnePurchase').size().plot(kind='pie',ax=ax1,autopct=label_function)
ax1.set_xlabel('TimeTakenForOnePurchase')
ax1.set_ylabel('')
sns.countplot(df['TimeTakenForOnePurchase'],hue=df['DeviceType'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. When using desktop to do the online shopping, mostly it takes 6-10 mins for one purchase.

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2, figsize=(18, 6))
df.groupby('Rating-ProcessingSpeed').size().plot(kind='pie',ax=ax1,autopct=label_function)
ax1.set_xlabel('Rating-ProcessingSpeed')
ax1.set_ylabel('')
sns.countplot(df['Rating-ProcessingSpeed'],hue=df['Browser'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. When using google chrome for accessing the websites, the processing speed is better than other browsers.

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2, figsize=(18, 6))
df.groupby('ChannelUsed-FirstVist').size().plot(kind='pie',ax=ax1,autopct=label_function)
ax1.set_xlabel('ChannelUsed-FirstVist')
ax1.set_ylabel('')
sns.countplot(df['ChannelUsed-FirstVist'],hue=df['ChannelUsed-AfterFirstVist'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. Search engine is mostly used to visit the online store for the first time and more number of customers uses the same channel after first visit also.
# 2. The second higest number of channels used to visit after the first visit is application.

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2, figsize=(18, 6))
df.groupby('Rating-EaseOfWebsiteNavigation').size().plot(kind='pie',ax=ax1,autopct=label_function)
ax1.set_xlabel('Rating-EaseOfWebsiteNavigation')
ax1.set_ylabel('')
sns.countplot(df['Rating-EaseOfWebsiteNavigation'],hue=df['DeviceType'])
plt.xticks(rotation=90)
plt.show()

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2, figsize=(18, 6))
df.groupby('Rating-PaymentMethod').size().plot(kind='pie',ax=ax1,autopct=label_function)
ax1.set_xlabel('Rating-PaymentMethod')
ax1.set_ylabel('')
sns.countplot(df['Rating-PaymentMethod'],hue=df['PaymentOption'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. Most of the customers who uses credit/debit card payment options are strongly agree that the online retailers has convenient payment methods.

# %%
plt.figure(figsize=(16,8))
sns.countplot(df['City'],hue=df['OnlineRetailers-RecommendToFriends'])
plt.legend(loc='upper right')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. In the cities Solan,Moradabad and Bullandshahr people are mostly using only Amazon and they recommend amazon to their friends.
# 2. In the city Delhi and Greater Noida, amazon and flipkart is mostly used and recommened to their freinds.
# 3. In Banagalore, Amazon and Myntra mostly used by customers and it is recommended to their freinds and followed by flipkart is next highest recommended retailer.

# %%
plt.figure(figsize=(16,8))
sns.countplot(df['OnlineRetailers-WebsiteEfficiency'],hue=df['Browser'])
plt.legend(loc='upper right')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. Amazon and flipkart website efficiency is better while using Google chrome.
# 2. Paytm website efficiency is better while using Safari.

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2, figsize=(18, 6))
df.groupby('OnlineRetailers-LongerDeliveryPeriod').size().plot(kind='pie',ax=ax1,autopct=label_function)
ax1.set_xlabel('OnlineRetailers-LongerDeliveryPeriod')
ax1.set_ylabel('')
sns.countplot(df['OnlineRetailers-LongerDeliveryPeriod'],hue=df['City'],ax=ax2)
plt.legend(loc='upper right')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. Paytm takes longer delivery time to deliver the orders in the cities Greater Noida, Karnal and followed by Delhi.
# 2. Snapdeal takes longer deleivery time in Delhi and followed by Bangalore.
# 3. Flipkart takes more delivery time in Banaglore.
# 4. Amazon takes more delivery time in Solan.

# %%
plt.figure(figsize=(16,6))
sns.countplot(df['Pincode'],hue=df['OnlineRetailers-LongerDeliveryPeriod'],palette='Set2')
plt.legend(loc='upper right')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. Paytm takes longer time to deliver in the pin code 201308(Greater Noida) and 132001(Haryana).

# %%
plt.figure(figsize=(16,6))
sns.countplot(df['OnlineRetailers-LongerPageLoadingTime'],hue=df['Browser'],palette='Set2')
plt.legend(loc='upper right')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. Myntra takes longer page load time with google chrome browser.

# %%
plt.figure(figsize=(12,10))
df.groupby('OnlineRetailers-LateDeclarationOfPrice').size().plot(kind='pie',autopct=label_function)
plt.xlabel('OnlineRetailers-LongerDeliveryPeriod')
plt.ylabel('')
plt.show()

# %% [markdown]
# 1. Mostly Mytra declaring the price lately while purchasing, which will not give better feeling for all the customers.

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2, figsize=(18, 6))
df.groupby('OnlineRetailers-SpeedDelivery').size().plot(kind='pie',ax=ax1,autopct=label_function)
ax1.set_xlabel('OnlineRetailers-SpeedDelivery')
ax1.set_ylabel('')
sns.countplot(df['OnlineRetailers-SpeedDelivery'],hue=df['City'],ax=ax2)
plt.legend(loc='upper right')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. Amazon is the best retailer for speed delivery.
# 2. Amazon and Flipkart doing speed delivery in Delhi.

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2, figsize=(18, 6))
df.groupby('NoOfPurchaseInLastYear').size().plot(kind='pie',ax=ax1,autopct=label_function)
ax1.set_xlabel('NoOfPurchaseInLastYear')
ax1.set_ylabel('')
sns.countplot(df['NoOfPurchaseInLastYear'],hue=df['City'],ax=ax2)
plt.legend(loc='upper right')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. In Delhi and Greater Noida more customers purchased more than 40 times in last 1 year.
# 2. In Delhi highest number of customers purchased less than 10 times in the last one year.

# %%
plt.figure(figsize=(12,10))
df.groupby('OnlineRetailers-VarietyOfOffer').size().plot(kind='pie',autopct=label_function)
plt.xlabel('OnlineRetailers-VarietyOfOffer')
plt.ylabel('')
plt.show()

# %% [markdown]
# 1. It clearly shows that amazon and flipkart provides more variety of offers than other retailers.

# %%
plt.figure(figsize=(18,6))
sns.countplot(df['OnlineRetailers'],hue=df['City'])
plt.legend(loc='upper right')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 8))
df.groupby('OnlineRetailers').size().plot(kind='pie',autopct=label_function)
plt.xlabel('OnlineRetailers')
plt.ylabel('')
plt.show()

# %% [markdown]
# 1. Almost more number of customers used all the online retailers(Amazon,Flipkart,Paytm,Snapdeal,Myntra)

# %%
plt.figure(figsize=(16,8))
plt.title('Comparision between online retailers customers used and online retailers they recommend to their friends.')
sns.countplot(df['OnlineRetailers'],hue=df['OnlineRetailers-RecommendToFriends'],palette='Set2')
plt.legend(loc='upper right')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. The customers who used all the online shopping websites are mostly recommending Amazon and Flipkart to their freinds

# %%
from sklearn.preprocessing import LabelEncoder
for col in df.columns:
    df[col]=LabelEncoder().fit_transform(df[col])

# %%
df.skew().sort_values()
# Out:
# ChannelUsed-FirstVist                       -2.469485
# ScreenSizeOfDevice                          -1.308503
# Rating-Return&ReplacementPloicy             -1.305697
# Rating-UserFriendly                         -1.270908
# AbandonShopping                             -0.867449
#                                                ...
# OnlineRetailers-SpeedDelivery                1.061243
# Rating-EmpathyTowardsCustomer                1.105678
# Rating-AvailablityOfCommunicationChannels    1.119422
# OnlineRetailers-VarietyOfOffer               1.186071
# Browser                                      1.710244
# Length: 71, dtype: float64

# %% [markdown]
# We have skewed data in our data set which needs to be handled before building the model.

# %% [markdown]
# ## Conclusion/Insight from the above observations

# %% [markdown]
# Conclusion/Insights from analysis:
# 1.	Amazon is the top and highly recommended website/application for online shopping. Amazon is the customer’s primacy choice of online shopping websites for various reasons like website speed, quick online purchase, various payment options, speedy delivery, better website efficiency and more variety of offers for the products and etc.
# 2.	Flipkart is the second top online shopping website for the reasons like providing better relevant product information, more payment options availability, provides more variety of offers and speed delivery in Delhi.
# 3.	In Bangalore, Myntra also mostly used by customers, and it is recommended to their friends.
#
# ##### Following are the few of improvement areas for online retailers to retain their customers. This is purely based on customers experience and the feedback given in the dataset.
#
# 	Snapdeal:
# 1.	Snapdeal has limited mode of payment options for products. It should not be the case for customer’s dissatisfaction.
# 2.	Team should focus on reducing the delivery time.
# 3.	Customers face frequent disruption with Snapdeal site/application. It shows that website instability. Team may focus on improving the website stability.
# 4.	Team can focus on reducing the delivery time in Delhi and Bangalore.
#
# 	Myntra:
# 1.	Most of the customers says, Myntra does the late declaration on Prices. It will reduce the application reliability on the customers. So team can focus on reducing such kind of cases.
# 2.	Team can focus on reducing the website/application loading time.
# 3.	Team can focus on reducing the disruptions during the online shopping
#
# 	Paytm:
# 1.	Very smaller number of customers rated Paytm as reliable website/application. It shows that, customers may not feel Paytm as the reliable retailer. The team should try to create strong reliability within the customers.
# 2.	Team can focus on reducing the website/application loading time.
# 3.	Team can focus on reducing the delivery time.
#
# 	Flipkart:
# 1.	Very less customers rated website/application speed is better in Flipkart. It shows that they do not feel good about the website/application speed. May be the Flipkart team focus on improving the speed of the website/application.
# 2.	May be the team can try to reduce the delay on loading images.
# 3.	Flipkart should focus on reducing delivery time in Bangalore.
#
# 	Amazon:
# 1.	More customers feels amazon takes longer time to get logged in. May be amazon can look into that area to reduce the login time.
# 2.	May be the application team look at the area to reduce the image loading time.
# 3.	More number of customers says amazon has frequent disruption when moving from one page to another page. This may be because of more load on the website at a time, so application team may try to reduce this kind of disruption for the customers.
# 4.	In the city Solan most the customers uses Amazon website/application for online shopping but the speed of delivery is very slow in this city. Amazon team may concentrate on reducing delivery time in this city.
